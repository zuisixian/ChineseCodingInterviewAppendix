# %% [markdown]
# # Tavily Search

# %% [markdown]
# [Tavily's Search API](https://tavily.com) is a search engine built specifically for AI agents (LLMs), delivering real-time, accurate, and factual results at speed.
#
# ## Overview
#
# ### Integration details
# | Class | Package | Serializable | [JS support](https://js.langchain.com/docs/integrations/tools/tavily_search) |  Package latest |
# | :--- | :--- | :---: | :---: | :---: |
# | [TavilySearchResults](https://python.langchain.com/api_reference/community/tools/langchain_community.tools.tavily_search.tool.TavilySearchResults.html) | [langchain-community](https://python.langchain.com/api_reference/community/index.html) | ❌ | ✅ |  ![PyPI - Version](https://img.shields.io/pypi/v/langchain-community?style=flat-square&label=%20) |
#
# ### Tool features
# | [Returns artifact](/docs/how_to/tool_artifacts/) | Native async | Return data | Pricing |
# | :---: | :---: | :---: | :---: |
# | ✅ | ✅ | Title, URL, content, answer | 1,000 free searches / month |
#
#
# ## Setup
#
# The integration lives in the `langchain-community` package. We also need to install the `tavily-python` package.

# %%
# %pip install -qU "langchain-community>=0.2.11" tavily-python
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 33.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 415.1/415.1 kB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.3 MB/s eta 0:00:00

# %% [markdown]
# ### Credentials
#
# We also need to set our Tavily API key. You can get an API key by visiting [this site](https://app.tavily.com/sign-in) and creating an account.

# %%
import getpass
import os

if not os.environ.get("TAVILY_API_KEY"):
    os.environ["TAVILY_API_KEY"] = getpass.getpass("Tavily API key:\n")
# Out:
# Tavily API key:
# ··········

# %% [markdown]
# It's also helpful (but not needed) to set up [LangSmith](https://smith.langchain.com/) for best-in-class observability:

# %%
# os.environ["LANGSMITH_TRACING"] = "true"
# os.environ["LANGSMITH_API_KEY"] = "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"

# %% [markdown]
# ## Instantiation
#
# Here we show how to instantiate an instance of the Tavily search tools, with

# %%
from langchain_community.tools import TavilySearchResults

tool = TavilySearchResults(
    max_results=5,
    search_depth="advanced",
    include_answer=True,
    include_raw_content=True,
    include_images=True,
    # include_domains=[...],
    # exclude_domains=[...],
    # name="...",            # overwrite default tool name
    # description="...",     # overwrite default tool description
    # args_schema=...,       # overwrite default args_schema: BaseModel
)

# %% [markdown]
# ## Invocation
#
# ### [Invoke directly with args](/docs/concepts/tools)
#
# The `TavilySearchResults` tool takes a single "query" argument, which should be a natural language query:

# %%
tool.invoke({"query": "What happened at the last wimbledon"})
# Out:
# [{'title': 'Wimbledon - latest news, breaking stories and comment',
#   'url': 'https://www.the-independent.com/topic/wimbledon',
#   'content': "Wimbledon - latest news, breaking stories and comment - The Independent Independent Wimbledon Rafael Nadal will retire after the Davis Cup with plenty of records and big numbers by his name A look at Rafael Nadal's 22 Grand Slam titles as he prepares to retire after the Davis Cup Rafael Nadal's farewell at the Davis Cup: When he'll play, how to watch on TV and more to know Tennis Channel takes Jon Wertheim off the air for comment about Wimbledon champ Barbora Krejcikova Mother ‘living in hell’ after girl, 8, dies in Wimbledon school crash AI umpires at Wimbledon will be game, set and match for tennis New Wimbledon system explained Wimbledon reveals new schedule for 2025 finals",
#   'score': 0.45420644,
#   'raw_content': "Wimbledon - latest news, breaking stories and comment - The Independent\nJump to content\nUS EditionChange\nUK EditionEdición en Español\nSign up to our newslettersSupport Now\nLog in / Register\nIndependent\nUS election\nSupport Now\nMenu\n\nNews\nNews\nUS\nUS election 2024\nUK\nEurope\nWorld\nUS Politics\nUK Politics\nHealth\nBusiness\nMoney\nScience\nSpace\nNews Videos\n\n\nSports\nSports\nUS Sports\nSoccer\nFormula 1\nUFC\nRugby Union\nCricket\nTennis\nBoxing\nCycling\nGolf\nSports Videos\n\n\nVoices\nVoices\nEditorials\nLetters\n\n\nCulture\nCulture\nMovies\nTV & Radio\nMusic\nGames\nBooks\nArt\nPhotography\nTheatre & Dance\nCulture Videos\n\n\nLifestyle\nLifestyle\nTech\nFood & Drink\nFashion\nLove & Sex\nWomen\nHealth & Families\nRoyal Family\nMotoring\nElectric Vehicles\nLifestyle Videos\n\n\nTravel\nTravel\nNews & Advice\nSimon Calder\nUSA\nUK\nEurope\nAsia\nInspiration\nCity Guides\nSustainable Travel\n\n\nPremium\nPremium\nEditorials\nVoices\nLong Reads\nPolitics Explained\nNews Analysis\n\n\n\nMore\nBest\n\nHome & Garden\nTech\nFashion & Beauty\nFood & Drink\nKids\nBooks\nTravel & Outdoors\nSports & Fitness\nDeals\n\nClimate\n\nNews\nClimate 100\nVoices\nSustainable Living\nExplained\nClimate Videos\nElectric vehicles\nSGI\n\nTV\n\nBehind The Headlines\nOn The Ground\nDecomplicated\nYou Ask The Questions\nBinge Watch\nMusic Box\nLove Lives\nTravel Smart\n\nWatch on your TV\n\n\nIndy100\n\nCrosswords & Puzzles\nMost Commented\nNewsletters\nAsk Me Anything\nVirtual Events\nVouchers\n\n\nThank you for registering\nPlease refresh the page or navigate to another page on the site to be automatically logged inPlease refresh your browser to be logged in\nWimbledon\n\nTennis\nAustralian great and long-time Davis Cup captain Neale Fraser dies aged 91\n\nCrime\nGirl aged 13 locked up for stabbing adoptive mother\n\nBusiness\nGrand Prix and Wimbledon drive Travelodge bookings but cost pressures linger\n\nNews\nMatteo Berrettini gives Italy a 1-0 lead over the Netherlands in the Davis Cup final\n\nTennis\nAndy Murray and Novak Djokovic’s magnificent seven grand slam finals\n\nTennis\nAndy Murray’s highs and lows as he returns to coach Novak Djokovic\n\nNews\nThe man who ended Nadal's career helps the Netherlands take a Davis Cup lead against Germany\n\nUK\nTennis champion Jamie Murray ‘very proud’ to receive honorary degree\n\nNews\nJasmine Paolini and Italy beat Slovakia to win the Billie Jean King Cup\n\nNews\nFrom Novak Djokovic to Iga Swiatek, players reflect on Rafael Nadal's career and retirement\n\nTennis\nRafael Nadal ends an era in which he unleashed one of sport’s greatest weapons\n\nNews\nShaun White's new halfpipe league to air on NBC\n\nNews\nRoger Federer tells friend and rival Rafael Nadal that he made him enjoy tennis more\n\nNews\nRafael Nadal will retire after the Davis Cup with plenty of records and big numbers by his name\n\nNews\nA look at Rafael Nadal's 22 Grand Slam titles as he prepares to retire after the Davis Cup\n\nTennis\nEmma Raducanu makes winning return to action as GB chase BJK Cup quarter-final\n\nNews\nRafael Nadal's farewell at the Davis Cup: When he'll play, how to watch on TV and more to know\n\nTennis\nTennis Channel axes US journalist after comment about Krejcikova\n\nHealth & Families\nBritish No1 tennis star Katie Boulter: ‘I’m coming out of my shell’\n\nNews\nUS Open finalist Taylor Fritz talks League of Legends, why he hated tennis and how he copied Sampras\n\nCrime\nCovid denier jailed for online posts encouraging violence against Chris Whitty\n\nNews\nTennis Channel takes Jon Wertheim off the air for comment about Wimbledon champ Barbora Krejcikova\n\nUK\nKate continues return to duties with Festival of Remembrance appearance\n\nTennis\nZheng Qinwen powers into final on debut at WTA Finals\n\nUK\nCamilla’s chest infection: How the royals’ health troubles stacked up in 2024\n\nUK\nKemi Badenoch: The darling of the Tory right bidding to lead them back to power\n\nTen ...
#  {'title': 'Wimbledon final: Carlos Alcaraz beats Daniil Medvedev to return',
#   'url': 'https://apnews.com/article/wimbledon-7-12-2024-results-men-semifinals-eb20db1af56ec59250b6fd44f9c60db4',
#   'content': 'Carlos Alcaraz of Spain plays a forehand return to Daniil Medvedev of Russia during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. Carlos Alcaraz of Spain plays a forehand return to Daniil Medvedev of Russia during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. Daniil Medvedev of Russia plays a forehand return to Carlos Alcaraz of Spain during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. Carlos Alcaraz of Spain plays a forehand return to Daniil Medvedev of Russia during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024.',
#   'score': 0.3436946,
#   'raw_content': 'Copyright 2025 The Associated Press. All Rights Reserved.\nCarlos Alcaraz and Novak Djokovic will meet in the Wimbledon men’s final again\nCarlos Alcaraz and Novak Djokovic will meet in the Wimbledon men’s final again\nCarlos Alcaraz of Spain celebrates after defeating Daniil Medvedev of Russia in their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Kirsty Wigglesworth)\nNovak Djokovic of Serbia plays a backhand return to Lorenzo Musetti of Italy during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Kirsty Wigglesworth)\nLorenzo Musetti of Italy reacts during his semifinal match against Novak Djokovic of Serbia at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Alberto Pezzali)\nDaniil Medvedev of Russia reacts after missing a shot as he plays against Carlos Alcaraz of Spain during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Mosa’ab Elshamy)\nCarlos Alcaraz of Spain celebrates after defeating Daniil Medvedev of Russia in their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Mosa’ab Elshamy)\nCarlos Alcaraz of Spain reacts during his semifinal match against Daniil Medvedev of Russia at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Kirsty Wigglesworth)\nNovak Djokovic of Serbia reacts during his semifinal match against Lorenzo Musetti of Italy at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Alberto Pezzali)\nDaniil Medvedev of Russia plays a backhand return to Carlos Alcaraz of Spain during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Mosa’ab Elshamy)\nCarlos Alcaraz of Spain plays a forehand return to Daniil Medvedev of Russia during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Kirsty Wigglesworth)\nCarlos Alcaraz, right, of Spain reacts during his semifinal match against Daniil Medvedev of Russia at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Alberto Pezzali)\nCarlos Alcaraz of Spain attempts to play a return to Daniil Medvedev of Russia during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Mosa’ab Elshamy)\nCarlos Alcaraz of Spain plays a forehand return to Daniil Medvedev of Russia during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Alberto Pezzali)\nCarlos Alcaraz of Spain reacts during his semifinal match against Daniil Medvedev of Russia at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Kirsty Wigglesworth)\nDaniil Medvedev of Russia plays a forehand return to Carlos Alcaraz of Spain during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Kirsty Wigglesworth)\nDaniil Medvedev of Russia plays a forehand return to Carlos Alcaraz of Spain during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Kirsty Wigglesworth)\nChair umpire Eva Asderaki watches play during the Carlos Alcaraz of Spain and Daniil Medvedev of Russia semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Alberto Pezzali)\nCarlos Alcaraz, right, of Spain is congratulated by Daniil Medvedev of Russia following their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Alberto Pezzali)\nDaniil Medvedev of Russia plays a backhand return to Carlos Alcaraz of Spain during their semifinal match at the Wimbledon tennis championships in London, Friday, July 12, 2024. (AP Photo/Mosa’ab Elshamy)\nCarlos Alcaraz of Spain plays a forehand return to Danii ...
#  {'title': 'Wimbledon 2024 Final result: Carlos Alcaraz beats Novak Djokovic ...',
#   'url': 'https://apnews.com/article/wimbledon-7-14-2024-men-final-djokovic-alcaraz-29160fa7a3653edc1ba493940dddc5eb',
#   'content': "Food & Recipes Gardening Homes Travel Fashion Pets Mideast Wars Russia-Ukraine War Español China Asia Pacific Latin America Europe Africa Food & Recipes Gardening Homes Travel Fashion Pets ![Image 23: Carlos Alcaraz, left, of Spain holds his trophy after defeating Novak Djokovic, right, of Serbia in the men's singles final at the Wimbledon tennis championships in London, Sunday, July 14, 2024.(AP Photo/Kirsty Wigglesworth)](blob:https://apnews.com/7fbd8254586292e1bc6d646fe8d717fc) 21 of 24\xa0|\xa0Carlos Alcaraz, left, of Spain holds his trophy after defeating Novak Djokovic, right, of Serbia in the men’s singles final at the Wimbledon tennis championships in London, Sunday, July 14, 2024.(AP Photo/Kirsty Wigglesworth) ![Image 47: Carlos Alcaraz, left, of Spain holds his trophy after defeating Novak Djokovic, right, of Serbia in the men's singles final at the Wimbledon tennis championships in London, Sunday, July 14, 2024.(AP Photo/Kirsty Wigglesworth)](blob:https://apnews.com/7fbd8254586292e1bc6d646fe8d717fc)",
#   'score': 0.29894704,
#   'raw_content': "Published Time: 2024-07-14T07:04:11\nWimbledon 2024 Final result: Carlos Alcaraz beats Novak Djokovic, defends title | AP News\nEnable accessibility\nAdvertisement\nMenu\n\nMenu\n\n\nWorld\n\n\nU.S.\n\n\nPolitics\n\n\nSports\n\n\nEntertainment\n\n\nBusiness\n\n\nScience\n\n\nFact Check\n\n\nOddities\n\n\nBe Well\n\n\nNewsletters\nNewsletters\nAP News Alerts Keep your pulse on the news with breaking news alerts from The AP.The Morning Wire Our flagship newsletter breaks down the biggest headlines of the day.Ground Game Exclusive insights and key stories from the world of politics.Beyond the Story Executive Editor Julie Pace brings you behind the scenes of the AP newsroom.AP Entertainment Wire Get AP's first personalized newsletter delivering you entertainment news twice a week.AP Top 25 Women's Basketball Poll Alerts Women's college basketball poll alerts and updates.\nSee All Newsletters\n\n\nPhotography\n\n\nAP Investigations\n\n\nClimate\nSECTIONS\nIndigenous peoples and climate Climate Questions Climate Migration India Focus\nTOP STORIES\n\n$75 million was awarded to plant trees in places that badly need them. In anti-DEI push, that's over\nMidwest winters are changing. So is the ancient sport of falconry\nNew stove that plugs into a normal wall outlet could be major gain for health and the climate\n\n\n\nHealth\nTOP STORIES\n\nRenowned geneticist Francis Collins retires from NIH, urging 'respect' for embattled workers\nPope had coughing fit, inhaled vomit and now requires assisted ventilation, Vatican says\nHarsh flu season has health officials worried about brain complications in children\nHow to practice healthy fasting during Ramadan\nDoes lip balm help chapped lips? Here's what to know\nMore adults are wondering if they have autism. Here are tips to seek a diagnosis\n\n\n\nTech\nSECTIONS\nArtificial Intelligence Social Media\nTOP STORIES\n\nHow to watch — and stream — the 2025 Oscars show and red carpet\nMicrosoft shutting down Skype in May\nThousands report outage affecting Microsoft services like Outlook\n\n\n\nLifestyle\nSECTIONS\nFood & Recipes Gardening Homes Travel Fashion Pets\nTOP STORIES\n\nMiami Beach mayor says no to getting back together a year after breaking up with spring breakers\nFerragamo pops red with a Milan collection inspired by the world of dance\nRocker Victoria De Angelis spins a DJ set as Dolce & Gabbana's Milan show spills onto the streets\n\n\n\nReligion\nTOP STORIES\n\nMuslims in the Middle East observe Ramadan amid political upheavals and postwar turmoil\nPope gets visit from Vatican secretary of state, says he's sharing the suffering of all sick people\nIsrael cuts off Gaza aid to pressure Hamas to accept a new ceasefire proposal\n\nNewsletters\nWorld of Faithtest Comprehensive global coverage of how religion shapes our world.\nSee All Newsletters\n\n\nEspañol\nTOP STORIES\n\nIsrael corta la ayuda a Gaza para presionar a Hamás para que acepte un nuevo plan de cese el fuego\nPérdida, preocupación y oraciones marcan el inicio del Ramadán en Gaza\nAntes críticos con Medicaid, ahora los republicanos se unen para defenderlo\nReino Unido, Francia y Ucrania acuerdan preparar un plan de alto el fuego para la guerra en Ucrania\nEn discurso ante el Congreso argentino, Milei promete acuerdo con el FMI y destaca logros económicos\n\n\n\nQuizzes\n\n\nPress Releases\n\n\nMy Account\n\n\n...\n\n\nWorld\n\nMideast Wars\nRussia-Ukraine War\nEspañol\nChina\nAsia Pacific\nLatin America\nEurope\nAfrica\nAustralia\nMiddle East\nGlobal Elections\n\n\n\nU.S.\n\n\nPolitics\n\nTrump cabinet confirmation tracker\nWhite House\nCongress\nU.S. Supreme Court\nTrump’s presidential promises\n2025 Election Calendar\n\n\n\nSports\n\nNBA\nNHL\nMen’s College Basketball\nMen’s Top 25\nWomen’s College Basketball\nWomen’s Top 25\nMLB\nNFL\nAuto Racing\nSoccer\n\n\n\nEntertainment\n\nMovie Reviews\nWhat to Stream\nTelevision\nBook Reviews\nMusic\nCelebrity Interviews\n\n\n\nBusiness\n\nInflation\nFinancial Mark ...
#  {'title': "Wimbledon final: Novak Djokovic targets Federer's record eight titles",
#   'url': 'https://www.nytimes.com/athletic/5635500/2024/07/13/wimbledon-final-djokovic-alcaraz-federer-record/',
#   'content': "WIMBLEDON — Novak Djokovic is one win away from equalling Roger Federer's record of eight Wimbledon titles. Beat Carlos Alcaraz in the men's",
#   'score': 0.29810348,
#   'raw_content': "Published Time: 2024-07-13T22:46:22+00:00\nWimbledon final: Novak Djokovic targets Federer’s record eight titles – again - The Athletic\n\n Tennis\n\nWimbledon final: Novak Djokovic targets Federer’s record eight titles – again\n\nBy Charlie Eccleshare\nJul 13, 2024\n\nWIMBLEDON — Novak Djokovic is one win away from equalling Roger Federer’s record of eight Wimbledon titles. Beat Carlos Alcaraz in the men’s singles final on Sunday and he will equal the feat of the men’s player who has become more synonymous with the All England Club than any other.\nA hallmark of Federer’s popularity was his status as crowd favourite. He was so beloved that by the time he had won six titles, he even had the crowd on his side when he beat Andy Murray — bidding to become the first British player to win the men’s title in 76 years — in the 2012 final. It was the final now remembered for Murray’s tearful realisation that he was “getting closer”; the next year, he finally broke the hoodoo by beating none other than Djokovic in three sets.\nAdvertisement\nNow, 12 years on from Federer’s reversal of home advantage, Djokovic’s relationship with the Wimbledon crowd as he stands on the edge of history is rather more complicated.\nAfter soundly and serenely beating Holger Rune on Monday, Djokovic accused the Wimbledon crowd of “disrespect“, believing that a large number of spectators had been booing him during the match. “Have a goooooooood night,” he said to the booers, even though the vast majority had been saying “Ruuuuuune” in support of his Danish opponent.\n\nDjokovic’s crowd interactions are frequently memorable (Mike Hewitt/Getty Images)\nOn Friday, there were some boos when Djokovic celebrated his semifinal victory over Lorenzo Musetti by playing an imaginary violin (which was actually aimed at his daughter Tara, who is learning the instrument), but lots of applause followed during his on-court interview.\nNowadays, Djokovic is generally liked and respected at Wimbledon, but on Sunday he faces defending champion Alcaraz, who has charmed the crowds with his Cheshire Cat smile and outrageous shotmaking ability. The majority of Centre Court were definitely on his side during last year’s final against Djokovic — this can partly be explained by tennis’s perennial cognitive dissonance when it comes to supporting underdogs — and as the 24-time Grand Slam champion chases the 25th, as well as Federer’s Wimbledon title count, he is likely to have the opportunity to fuel himself with a siege mentality once again.\n\nDjokovic has made an art out of defying hostile crowds, thriving on the antagonism. He did it against Federer on this very court in the 2019 final. He did it to the same player in the U.S. Open final of 2015, when there were moments in which an uncomfortably partisan crowd were barely cheering when Djokovic won points.\n GO DEEPER The wisdom of crowds: Tricolores, trumpets, and truculence at Roland GarrosCrowd support in an individual sport is an intensely personal thing, rarely more so than in tennis and with Djokovic. He evokes strong feelings, positive and negative, and it’s easy to understand why any player will take the ensuing reactions from fans personally — especially a player who has achieved everything there is to achieve and more in tennis.\nAdvertisement\nThere are some curious elements.\nOverwhelming favourites can often find themselves on the wrong side of fans when the only thing they have done “wrong” is winning too quickly. Crowds want as much tennis as possible, but they still want their favourite (often the player they are temporarily against) to win. Just, not too much. This has happened to Alcaraz and to women’s world No 1 Iga Swiatek, who have on occasions looked mildly bewildered by cheers when they lose a point after being roared to a convincing first-set win.\n\nAlcaraz, like Djokovic, knows how to harness crowd energy (Julian Finney/Getty Images)\nSupport in tennis is not like football. Later on Sunda ...
#  {'title': 'Alcaraz DESTROYS Djokovic for 2nd Wimbledon, 4th ... - YouTube',
#   'url': 'https://www.youtube.com/watch?v=GlDHV7EtOk0',
#   'content': 'Comments228 · DRAMATIC ending to the final | The last 26 minutes in full | Alcaraz v Djokovic | Wimbledon 2024 · Soooo, What Happened To Novak',
#   'score': 0.27850494,
#   'raw_content': "ANALYSIS: Alcaraz DESTROYS Djokovic for 2nd Wimbledon, 4th Major | THE SLICE\nThe Slice Tennis\n20200 subscribers\n496 likes\n15020 views\n14 Jul 2024\nCarlos Alcaraz has defeated Novak Djokovic to win Wimbledon for the second year in a row, this time with a dominant 3 set performance. Stephen reacts to the match, the storylines, and the history that Alcaraz has made. Leave your thoughts below, and thanks for subscribing!\n\n0:00 Intro\n1:57 Prediction vs Outcome\n4:00 Stats from Wimbledon Final\n6:00 Set 1 Analysis\n7:43 Set 2 Analysis\n8:30 Set 3 Analysis\n11:06 Recap: Alcaraz defeats Djokovic\n14:28 A word for Djokovic fans\n15:59 Changing of the guard\n\nLISTEN to The Slice:\nApple - https://podcasts.apple.com/ca/podcast/the-slice-tennis-podcast/id1307710150\nSpotify - https://open.spotify.com/show/5uz9IsyvnruYUHP3lq3Bx7\n\nJOIN OUR PATREON: https://www.patreon.com/theslicetennis\nMORE FROM THE SLICE: https://linktr.ee/theslice\nMERCH: https://www.theslicetennis.com/shop\n\nFOLLOW\n►Instagram: https://www.instagram.com/theslicetennis\n🔹 Twitter: https://twitter.com/theslicetennis\n►Website: https://www.theslicetennis.com/\n228 comments\n\nCarlos freaking alarz has done it beats jokovic for the second year in a row in the wimon final in three sets this time and there's just not enough amazing things to say about this kid he is big time he finds his best tennis in the biggest moments it was a very weird match it was not the match that I think a lot of us were hoping for as far as an epic jokovic didn't have the level in the first two sets and alarz absolutely pounced on him earlyer and just really got him up against the ropes but did get interesting in that third set alz squandered three Championship points actually four in total and jokovic almost started making people think he was having a comeback but alra slams the door we're GNA break it down what happened in this match what it means for the history of tennis what it means for alcra we're gonna get all into it this is the slice presented by betway thanks for being here let's get going oh my gosh there's just so much to talk about there the match the the records that alarz now has or the the record that he has in majors and against jokovic and all this it's just it's just nuts 21 years old we've I said it on Twitter I really think we've never seen anyone like him as a 21-year-old winning on all surfaces two wimbledon's now one French Open one US Open unreal if you're new here welcome to the slice I'm Stephen Bon I'm your host and I would love it if you subscribed because we are trying to get to 20,000 subscribers and you would help us out in doing that we just had a great live stream with our podcast co-host JP huy and a few special guests so you can go watch the recording of that we watched it all live and it was a match it went in a way how I expected because if you watch a previous video to this I called it I predicted alz in four he gets it done in three and a quick word for the haters if you thought it was just a jokovic hater because I picked ALR to win you're out to lunch literally last year at The Wimbledon final I predicted jokovic to win and alcr won so I picked jokovic or alcr this year because of logical reasoning and he won because he played the way I thought he would and he was too much for jokovic like I thought he was going to be so put some respect on the slice name we know what we're talking about we're now eight for 10 as far as videos when I make a video saying this guy will be this guy to win this eight out of 10 have been right the only times we've not gotten it right was the W 20123 Wimbledon final when I bet on sorry that was wrong earlier when I said uh the that about jokovic letting me down the only times I've lost is when I've bet against jokovic so I bet I I thought that um or no sorry I picked jokovic to win last year's Wimbledon I lost that one and I picked jokovic to win uh the 2022 rolling garos quarterfinal and Nadal got ...

# %% [markdown]
# ### [Invoke with ToolCall](/docs/concepts/tools)
#
# We can also invoke the tool with a model-generated ToolCall, in which case a ToolMessage will be returned:

# %%
# This is usually generated by a model, but we'll create a tool call directly for demo purposes.
model_generated_tool_call = {
    "args": {"query": "上海今天天气"},
    "id": "1",
    "name": "tavily",
    "type": "tool_call",
}
tool_msg = tool.invoke(model_generated_tool_call)

# The content is a JSON string of results
print(tool_msg.content[:400])
# Out:
# [{"title": "今天上海市天气_今日天气预报- 墨迹天气", "url": "https://tianqi.moji.com/today/china/shanghai/shanghai", "content": "首页 天气 下载 资讯 关于墨迹 天气 中国 上海市， 上海市， 中国 热门时景 更多 附近地区 更多 附近景点 更多 1  晴 晴 2°日出 06:41 晴 -2°日落 17:35 晴 02/07 *   周六 晴  晴 02/08 *   周日 晴  晴 02/09 *   周一 多云  阴 02/10 *   周二 阴  小雨 02/11 阴 02/12 *   周四 阴  阴 02/13 *   周五 小雨  小雨 02/14 *   周六 小雨  多云 02/15 *   周日 晴  多云 02/16 *   周一 阴  阴 02/17 *   周二 阴  多云

# %%
# The artifact is a dict with richer, raw results
{k: type(v) for k, v in tool_msg.artifact.items()}
# Out:
# {'query': str,
#  'follow_up_questions': NoneType,
#  'answer': str,
#  'images': list,
#  'results': list,
#  'response_time': float}

# %%
import json

# Abbreviate the results for demo purposes
print(json.dumps({k: str(v)[:200] for k, v in tool_msg.artifact.items()}, indent=2))
# Out:
# {
#   "query": "\u4e0a\u6d77\u4eca\u5929\u5929\u6c14",
#   "follow_up_questions": "None",
#   "answer": "\u4e0a\u6d77\u4eca\u5929\u5929\u6c14\u4e3a\u591a\u4e91\uff0c\u6c14\u6e29\u57286\u5ea6\u5de6\u53f3\uff0c\u98ce\u5411\u4e3a\u897f\u5317\u98ce\uff0c\u98ce\u901f\u4e3a2\u7ea7\u3002\u5929\u6c14\u8f83\u51c9\uff0c\u5efa\u8bae\u7a7f\u7740\u539a\u5916\u5957\u3002",
#   "images": "['http://n.sinaimg.cn/sh/transform/47/w550h297/20191213/dcd2-ikrsess2635177.png', 'http://imgbdb3.bendibao.com/shbdb/20197/25/20190725075035_98454.png', 'https://resource.zhoudaosh.com/files/cimages/2",
#   "results": "[{'url': 'https://tianqi.moji.com/today/china/shanghai/shanghai', 'title': '\u4eca\u5929\u4e0a\u6d77\u5e02\u5929\u6c14_\u4eca\u65e5\u5929\u6c14\u9884\u62a5- \u58a8\u8ff9\u5929\u6c14', 'content': '\u4e0a\u6d77\u5e02\u4eca\u5929\u5b9e\u51b5\uff1a6\u5ea6\u591a\u4e91\uff0c\u6e7f\u5ea6\uff1a71%\uff0c\u897f\u5317\u98ce\uff1a2\u7ea7\u3002\u767d\u5929\uff1a11\u5ea6,\u6674\u3002 \u591c\u95f4\uff1a\u6674\uff0c5\u5ea6\uff0c\u5929\u51c9\u4e86\uff0c\u58a8\u8ff9\u5929\u6c14\u5efa\u8bae\u60a8\u5728\u7f8a\u6bdb\u886b\u5916\u9762\u5957\u4e0a\u539a\u5916\u5957\uff0c\u5e74\u8001\u4f53\u5f31\u8005\u53ef\u4ee5\u7a7f\u7740\u5462\u5927\u8863\u589e\u52a0\u4fdd\u6696\u7cfb\u6570\u3002',",
#   "response_time": "34.98"
# }

# %% [markdown]
# ## Chaining
#
# We can use our tool in a chain by first binding it to a [tool-calling model](/docs/how_to/tool_calling/) and then calling it:
#
# import ChatModelTabs from "@theme/ChatModelTabs";
#
# <ChatModelTabs customVarName="llm" />

# %%
# | output: false
# | echo: false

# !pip install -qU langchain langchain-openai
# !pip install -qU dashscope
from langchain.chat_models import init_chat_model
from langchain_community.chat_models import ChatTongyi

# llm = init_chat_model(model="gpt-4o", model_provider="openai", temperature=0)
os.environ["DASHSCOPE_API_KEY"] = "sk-d721de7176c84925a199ffdf999d981c"
llm = ChatTongyi()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.6 MB/s eta 0:00:00

# %%
import datetime

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableConfig, chain

today = datetime.datetime.today().strftime("%D")
prompt = ChatPromptTemplate(
    [
        ("system", f"You are a helpful assistant. The date today is {today}."),
        ("human", "{user_input}"),
        ("placeholder", "{messages}"),
    ]
)

# specifying tool_choice will force the model to call this tool.
llm_with_tools = llm.bind_tools([tool])

llm_chain = prompt | llm_with_tools


@chain
def tool_chain(user_input: str, config: RunnableConfig):
    input_ = {"user_input": user_input}
    ai_msg = llm_chain.invoke(input_, config=config)
    tool_msgs = tool.batch(ai_msg.tool_calls, config=config)
    return llm_chain.invoke({**input_, "messages": [ai_msg, *tool_msgs]}, config=config)


tool_chain.invoke("现在恒生科技指数是多少")
# Out:
# AIMessage(content='截至2025年3月6日的数据，恒生科技指数的报价为5757.940，较昨日上涨了4.02%，涨幅222.300。请注意，这些数据可能会随市场波动而变化。', additional_kwargs={}, response_metadata={'model_name': 'qwen-turbo', 'finish_reason': 'stop', 'request_id': '56573af0-e58b-91c6-be0c-47f634d03824', 'token_usage': {'input_tokens': 12070, 'output_tokens': 60, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 12130}}, id='run-c5da75cd-8809-4102-ba65-0b22c42d7141-0')

# %% [markdown]
# Here's the [LangSmith trace](https://smith.langchain.com/public/b43232c1-b243-4a7f-afeb-5fba8c84ba56/r) for this run.

# %% [markdown]
# ## API reference
#
# For detailed documentation of all TavilySearchResults features and configurations head to the API reference: https://python.langchain.com/api_reference/community/tools/langchain_community.tools.tavily_search.tool.TavilySearchResults.html
